# %% [markdown]
# Create project in PyCharm

# %% [markdown]
# Open terminal window

# %% [markdown]
# # Adding default packages to new environments automatically

# %% [markdown]
# To automatically add default packages to each new environment that you create:
# Open Anaconda Prompt or terminal and run:

# %%
#!conda config --add create_default_packages jupyter numpy cookiecutter

# %% [markdown]
# Now, you can create new environments and the default packages will be installed in all of them.
#
# You can also edit the .condarc file with a list of packages to create by default.
#
# You can override this option at the command prompt with the --no-default-packages flag.

# %% [markdown]
# # Printing current environment name

# %%
# confirm environment name
# !conda info --envs
# Out:
# # conda environments:
# #
# base                     /Users/val/opt/anaconda3
# android                  /Users/val/opt/anaconda3/envs/android
# beam                     /Users/val/opt/anaconda3/envs/beam
# cookiecutter-data-science     /Users/val/opt/anaconda3/envs/cookiecutter-data-science
# dvc                      /Users/val/opt/anaconda3/envs/dvc
# dvc2                     /Users/val/opt/anaconda3/envs/dvc2
# microscope               /Users/val/opt/anaconda3/envs/microscope
# microscopeProject     *  /Users/val/opt/anaconda3/envs/microscopeProject
# nlp                      /Users/val/opt/anaconda3/envs/nlp

# %% [markdown]
# # Change to the repository's root

# %%
# If in an existing repository's notebook

# %%
# Change to the repo's root
# %cd ..
# Out:
# /Users/val/Google Drive/projects/microscopeProject/microscope

# %%
pwd
# Out:
# '/Users/val/Google Drive/projects/microscopeProject/microscope/notebooks'

# %% [markdown]
# ## Create new python project in pycharm first

# %% [markdown]
# Create a new python project in pycharm, then open terminal

# %%
# create project repository
#%conda install numpy cookiecutter
#%cookiecutter https://github.com/voklymchuk/cookiecutter-data-science
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# You've downloaded /Users/val/.cookiecutters/cookiecutter-data-science before. Is it okay to delete and re-download it? [yes]: ^C
# Aborted!

# %%
# alternatively if created a new repository above
# Change to the repository's root
# %cd microscope

# %%
ls
# Out:
# LICENSE              microscope/          reports/
# Makefile             microscope.egg-info/ setup.py
# README.md            models/              tests/
# docs/                notebooks/           tox.ini
# environment.yml      references/

# %%
pwd()
# Out:
# '/Users/val/Google Drive/projects/microscopeProject/microscope/notebooks'

# %% [markdown]
# # Install project requirements

# %%
# Link ./src/ with your notebook
# Run this in the project root
# %conda env update --file ../environment.yml
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# Downloading and Extracting Packages
# pip-20.3.2           | 1.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: / Ran pip subprocess with arguments:
# ['/Users/val/opt/anaconda3/envs/microscopeProject/bin/python', '-m', 'pip', 'install', '-U', '-r', '/Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt']
# Pip subprocess output:
# Obtaining file:///Users/val/Google%20Drive/projects/microscopeProject/microscope (from -r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 5))
# Requirement already satisfied: awscli in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from -r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (1.18.195)
# Collecting awscli
#   Downloading awscli-1.18.196-py2.py3-none-any.whl (3.5 MB)
#   Downloading awscli-1.18.196.tar.gz (1.4 MB)
#   Using cached awscli-1.18.195-py2.py3-none-any.whl (3.5 MB)
#   Downloading awscli-1.18.195.tar.gz (1.4 MB)
#   Downloading awscli-1.18.194-py2.py3-none-any.whl (3.5 MB)
#   Downloading awscli-1.18.194.tar.gz (1.4 MB)
#   Using cached awscli-1.18.193-py2.py3-none-any.whl (3.5 MB)
#   Downloading awscli-1.18.193.tar.gz (1.4 MB)
#   Downloading awscli-1.18.192-py2.py3-none-any.whl (3.5 MB)
#   Downloading awscli-1.18.192.tar.gz (1.4 MB)
#   Downloading awscli-1.18.191-py2.py3-none-any.whl (3.5 MB)
#   Downloading awscli-1.18.191.tar.gz (1.4 MB)
#   Downloading awscli-1.18.190-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.190.tar.gz (1.4 MB)
#   Downloading awscli-1.18.189-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.189.tar.gz (1.4 MB)
#   Downloading awscli-1.18.188-py2.py3-none-any.whl (3.4 MB)
#   Using cached awscli-1.18.188.tar.gz (1.4 MB)
#   Downloading awscli-1.18.187-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.187.tar.gz (1.4 MB)
#   Downloading awscli-1.18.186-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.186.tar.gz (1.4 MB)
#   Downloading awscli-1.18.185-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.185.tar.gz (1.4 MB)
#   Downloading awscli-1.18.184-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.184.tar.gz (1.4 MB)
#   Downloading awscli-1.18.183-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.183.tar.gz (1.4 MB)
#   Downloading awscli-1.18.182-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.182.tar.gz (1.4 MB)
#   Downloading awscli-1.18.181-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.181.tar.gz (1.4 MB)
#   Downloading awscli-1.18.180-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.180.tar.gz (1.4 MB)
#   Downloading awscli-1.18.179-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.179.tar.gz (1.4 MB)
#   Using cached awscli-1.18.178-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.178.tar.gz (1.4 MB)
#   Downloading awscli-1.18.177-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.177.tar.gz (1.3 MB)
#   Downloading awscli-1.18.176-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.176.tar.gz (1.3 MB)
#   Downloading awscli-1.18.175-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.175.tar.gz (1.3 MB)
#   Downloading awscli-1.18.174-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.174.tar.gz (1.3 MB)
#   Downloading awscli-1.18.173-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.173.tar.gz (1.3 MB)
#   Downloading awscli-1.18.172-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.172.tar.gz (1.3 MB)
#   Downloading awscli-1.18.171-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.171.tar.gz (1.3 MB)
#   Downloading awscli-1.18.170-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.170.tar.gz (1.3 MB)
#   Downloading awscli-1.18.169-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.169.tar.gz (1.3 MB)
#   Downloading awscli-1.18.168-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.168.tar.gz (1.3 MB)
#   Downloading awscli-1.18.167-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.167.tar.gz (1.3 MB)
#   Downloading awscli-1.18.166-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.166.tar.gz (1.3 MB)
#   Downloading awscli-1.18.165-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.165.tar.gz (1.3 MB)
#   Downloading awscli-1.18.164-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.164.tar.gz (1.3 MB)
#   Downloading awscli-1.18.163-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.163.tar.gz (1.3 MB)
#   Downloading awscli-1.18.162-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.162.tar.gz (1.3 MB)
#   Downloading awscli-1.18.161-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.161.tar.gz (1.3 MB)
#   Downloading awscli-1.18.160-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.160.tar.gz (1.3 MB)
#   Downloading awscli-1.18.159-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.159.tar.gz (1.3 MB)
#   Downloading awscli-1.18.158-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.158.tar.gz (1.3 MB)
#   Downloading awscli-1.18.157-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.157.tar.gz (1.3 MB)
#   Downloading awscli-1.18.156-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.156.tar.gz (1.3 MB)
#   Downloading awscli-1.18.155-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.155.tar.gz (1.3 MB)
#   Downloading awscli-1.18.154-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.154.tar.gz (1.3 MB)
#   Downloading awscli-1.18.153-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.153.tar.gz (1.3 MB)
#   Downloading awscli-1.18.152-py2.py3-none-any.whl (3.4 MB)
#   Downloading awscli-1.18.152.tar.gz (1.3 MB)
#   Downloading awscli-1.18.151-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.151.tar.gz (1.3 MB)
#   Downloading awscli-1.18.150-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.150.tar.gz (1.3 MB)
#   Downloading awscli-1.18.149-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.149.tar.gz (1.3 MB)
#   Downloading awscli-1.18.148-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.148.tar.gz (1.3 MB)
#   Downloading awscli-1.18.147-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.147.tar.gz (1.3 MB)
#   Downloading awscli-1.18.146-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.146.tar.gz (1.3 MB)
#   Downloading awscli-1.18.145-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.145.tar.gz (1.3 MB)
#   Downloading awscli-1.18.144-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.144.tar.gz (1.3 MB)
#   Downloading awscli-1.18.143-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.143.tar.gz (1.3 MB)
#   Downloading awscli-1.18.142-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.142.tar.gz (1.3 MB)
#   Downloading awscli-1.18.141-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.141.tar.gz (1.3 MB)
#   Downloading awscli-1.18.140-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.140.tar.gz (1.3 MB)
#   Downloading awscli-1.18.139-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.139.tar.gz (1.3 MB)
#   Downloading awscli-1.18.138-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.138.tar.gz (1.3 MB)
#   Downloading awscli-1.18.137-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.137.tar.gz (1.3 MB)
#   Downloading awscli-1.18.136-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.136.tar.gz (1.3 MB)
#   Downloading awscli-1.18.135-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.135.tar.gz (1.3 MB)
#   Downloading awscli-1.18.134-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.134.tar.gz (1.3 MB)
#   Downloading awscli-1.18.133-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.133.tar.gz (1.3 MB)
#   Downloading awscli-1.18.132-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.132.tar.gz (1.3 MB)
#   Downloading awscli-1.18.131-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.131.tar.gz (1.3 MB)
#   Downloading awscli-1.18.130-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.130.tar.gz (1.3 MB)
#   Downloading awscli-1.18.129-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.129.tar.gz (1.3 MB)
#   Downloading awscli-1.18.128-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.128.tar.gz (1.3 MB)
#   Downloading awscli-1.18.127-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.127.tar.gz (1.3 MB)
#   Downloading awscli-1.18.126-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.126.tar.gz (1.3 MB)
#   Downloading awscli-1.18.125-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.125.tar.gz (1.3 MB)
#   Downloading awscli-1.18.124-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.124.tar.gz (1.3 MB)
#   Downloading awscli-1.18.123-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.123.tar.gz (1.3 MB)
#   Downloading awscli-1.18.122-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.122.tar.gz (1.3 MB)
#   Downloading awscli-1.18.121-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.121.tar.gz (1.3 MB)
#   Downloading awscli-1.18.120-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.120.tar.gz (1.3 MB)
#   Downloading awscli-1.18.119-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.119.tar.gz (1.3 MB)
#   Downloading awscli-1.18.118-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.118.tar.gz (1.3 MB)
#   Downloading awscli-1.18.117-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.117.tar.gz (1.3 MB)
#   Downloading awscli-1.18.116-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.116.tar.gz (1.3 MB)
#   Downloading awscli-1.18.115-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.115.tar.gz (1.3 MB)
#   Downloading awscli-1.18.114-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.114.tar.gz (1.3 MB)
#   Downloading awscli-1.18.113-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.113.tar.gz (1.3 MB)
#   Downloading awscli-1.18.112-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.112.tar.gz (1.3 MB)
#   Downloading awscli-1.18.111-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.111.tar.gz (1.3 MB)
#   Downloading awscli-1.18.110-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.110.tar.gz (1.3 MB)
#   Downloading awscli-1.18.109-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.109.tar.gz (1.3 MB)
#   Downloading awscli-1.18.108-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.108.tar.gz (1.3 MB)
#   Downloading awscli-1.18.107-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.107.tar.gz (1.3 MB)
#   Downloading awscli-1.18.106-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.106.tar.gz (1.3 MB)
#   Downloading awscli-1.18.105-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.105.tar.gz (1.3 MB)
#   Downloading awscli-1.18.104-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.104.tar.gz (1.3 MB)
#   Downloading awscli-1.18.103-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.103.tar.gz (1.3 MB)
#   Downloading awscli-1.18.102-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.102.tar.gz (1.3 MB)
#   Downloading awscli-1.18.101-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.101.tar.gz (1.3 MB)
#   Downloading awscli-1.18.100-py2.py3-none-any.whl (3.3 MB)
#   Downloading awscli-1.18.100.tar.gz (1.3 MB)
#   Downloading awscli-1.18.99-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.99.tar.gz (1.3 MB)
#   Downloading awscli-1.18.98-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.98.tar.gz (1.3 MB)
#   Downloading awscli-1.18.97-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.97.tar.gz (1.3 MB)
#   Downloading awscli-1.18.96-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.96.tar.gz (1.3 MB)
#   Downloading awscli-1.18.95-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.95.tar.gz (1.3 MB)
#   Downloading awscli-1.18.94-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.94.tar.gz (1.3 MB)
#   Downloading awscli-1.18.93-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.93.tar.gz (1.3 MB)
#   Downloading awscli-1.18.92-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.92.tar.gz (1.3 MB)
#   Downloading awscli-1.18.91-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.91.tar.gz (1.3 MB)
#   Downloading awscli-1.18.90-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.90.tar.gz (1.3 MB)
#   Downloading awscli-1.18.89-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.89.tar.gz (1.3 MB)
#   Downloading awscli-1.18.88-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.88.tar.gz (1.3 MB)
#   Downloading awscli-1.18.87-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.87.tar.gz (1.3 MB)
#   Downloading awscli-1.18.86-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.86.tar.gz (1.3 MB)
#   Downloading awscli-1.18.85-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.85.tar.gz (1.3 MB)
#   Downloading awscli-1.18.84-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.84.tar.gz (1.3 MB)
#   Downloading awscli-1.18.83-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.83.tar.gz (1.3 MB)
#   Downloading awscli-1.18.82-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.82.tar.gz (1.2 MB)
#   Downloading awscli-1.18.81-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.81.tar.gz (1.2 MB)
#   Downloading awscli-1.18.80-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.80.tar.gz (1.2 MB)
#   Downloading awscli-1.18.79-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.79.tar.gz (1.2 MB)
#   Downloading awscli-1.18.78-py2.py3-none-any.whl (3.2 MB)
#   Downloading awscli-1.18.78.tar.gz (1.2 MB)
#   Downloading awscli-1.18.77-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.77.tar.gz (1.2 MB)
#   Downloading awscli-1.18.76-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.76.tar.gz (1.2 MB)
#   Downloading awscli-1.18.75-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.75.tar.gz (1.2 MB)
#   Downloading awscli-1.18.74-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.74.tar.gz (1.2 MB)
#   Downloading awscli-1.18.73-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.73.tar.gz (1.2 MB)
#   Downloading awscli-1.18.72-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.72.tar.gz (1.2 MB)
#   Downloading awscli-1.18.71-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.71.tar.gz (1.2 MB)
#   Downloading awscli-1.18.70-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.70.tar.gz (1.2 MB)
#   Downloading awscli-1.18.69-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.69.tar.gz (1.2 MB)
#   Downloading awscli-1.18.68-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.68.tar.gz (1.2 MB)
#   Downloading awscli-1.18.67-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.67.tar.gz (1.2 MB)
#   Downloading awscli-1.18.66-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.66.tar.gz (1.2 MB)
#   Downloading awscli-1.18.65-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.65.tar.gz (1.2 MB)
#   Downloading awscli-1.18.64-py2.py3-none-any.whl (3.1 MB)
#   Downloading awscli-1.18.64.tar.gz (1.2 MB)
#   Downloading awscli-1.18.63-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.63.tar.gz (1.2 MB)
#   Downloading awscli-1.18.62-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.62.tar.gz (1.2 MB)
#   Downloading awscli-1.18.61-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.61.tar.gz (1.2 MB)
#   Downloading awscli-1.18.60-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.60.tar.gz (1.2 MB)
#   Downloading awscli-1.18.59-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.59.tar.gz (1.2 MB)
#   Downloading awscli-1.18.58-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.58.tar.gz (1.2 MB)
#   Downloading awscli-1.18.57-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.57.tar.gz (1.2 MB)
#   Downloading awscli-1.18.56-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.56.tar.gz (1.2 MB)
#   Downloading awscli-1.18.55-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.55.tar.gz (1.2 MB)
#   Downloading awscli-1.18.54-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.54.tar.gz (1.2 MB)
#   Downloading awscli-1.18.53-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.53.tar.gz (1.2 MB)
#   Downloading awscli-1.18.52-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.52.tar.gz (1.2 MB)
#   Downloading awscli-1.18.51-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.51.tar.gz (1.2 MB)
#   Downloading awscli-1.18.50-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.50.tar.gz (1.2 MB)
#   Downloading awscli-1.18.49-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.49.tar.gz (1.2 MB)
#   Downloading awscli-1.18.48-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.48.tar.gz (1.2 MB)
#   Downloading awscli-1.18.47-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.47.tar.gz (1.2 MB)
#   Downloading awscli-1.18.46-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.46.tar.gz (1.2 MB)
#   Downloading awscli-1.18.45-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.45.tar.gz (1.2 MB)
#   Downloading awscli-1.18.44-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.44.tar.gz (1.2 MB)
#   Downloading awscli-1.18.43-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.43.tar.gz (1.2 MB)
#   Downloading awscli-1.18.42-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.42.tar.gz (1.2 MB)
#   Downloading awscli-1.18.41-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.41.tar.gz (1.2 MB)
#   Downloading awscli-1.18.40-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.40.tar.gz (1.2 MB)
#   Downloading awscli-1.18.39-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.39.tar.gz (1.2 MB)
#   Downloading awscli-1.18.38-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.38.tar.gz (1.2 MB)
#   Downloading awscli-1.18.37-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.37.tar.gz (1.2 MB)
#   Downloading awscli-1.18.36-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.36.tar.gz (1.2 MB)
#   Downloading awscli-1.18.35-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.35.tar.gz (1.2 MB)
#   Downloading awscli-1.18.34-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.34.tar.gz (1.2 MB)
#   Downloading awscli-1.18.33-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.33.tar.gz (1.2 MB)
#   Downloading awscli-1.18.32-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.32.tar.gz (1.2 MB)
#   Downloading awscli-1.18.31-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.31.tar.gz (1.2 MB)
#   Downloading awscli-1.18.30-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.30.tar.gz (1.2 MB)
#   Downloading awscli-1.18.29-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.29.tar.gz (1.2 MB)
#   Downloading awscli-1.18.28-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.28.tar.gz (1.2 MB)
#   Downloading awscli-1.18.27-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.27.tar.gz (1.2 MB)
#   Downloading awscli-1.18.26-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.26.tar.gz (1.2 MB)
#   Downloading awscli-1.18.25-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.25.tar.gz (1.2 MB)
#   Downloading awscli-1.18.24-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.24.tar.gz (1.2 MB)
#   Downloading awscli-1.18.23-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.23.tar.gz (1.2 MB)
#   Downloading awscli-1.18.22-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.22.tar.gz (1.2 MB)
#   Downloading awscli-1.18.21-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.21.tar.gz (1.2 MB)
#   Downloading awscli-1.18.20-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.20.tar.gz (1.2 MB)
#   Downloading awscli-1.18.19-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.19.tar.gz (1.2 MB)
#   Downloading awscli-1.18.18-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.18.tar.gz (1.2 MB)
#   Downloading awscli-1.18.17-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.17.tar.gz (1.2 MB)
#   Downloading awscli-1.18.16-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.16.tar.gz (1.2 MB)
#   Downloading awscli-1.18.15-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.15.tar.gz (1.2 MB)
#   Downloading awscli-1.18.14-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.14.tar.gz (1.2 MB)
#   Downloading awscli-1.18.13-py2.py3-none-any.whl (3.0 MB)
#   Downloading awscli-1.18.13.tar.gz (1.2 MB)
#   Downloading awscli-1.18.12-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.12.tar.gz (1.2 MB)
#   Downloading awscli-1.18.11-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.11.tar.gz (1.2 MB)
#   Downloading awscli-1.18.10-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.10.tar.gz (1.2 MB)
#   Downloading awscli-1.18.9-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.9.tar.gz (1.2 MB)
#   Downloading awscli-1.18.8-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.8.tar.gz (1.2 MB)
#   Downloading awscli-1.18.7-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.7.tar.gz (1.2 MB)
#   Downloading awscli-1.18.6-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.6.tar.gz (1.2 MB)
#   Downloading awscli-1.18.5-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.5.tar.gz (1.2 MB)
#   Downloading awscli-1.18.4-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.4.tar.gz (1.2 MB)
#   Downloading awscli-1.18.3-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.3.tar.gz (1.2 MB)
#   Downloading awscli-1.18.2-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.2.tar.gz (1.2 MB)
#   Downloading awscli-1.18.1-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.1.tar.gz (1.2 MB)
#   Downloading awscli-1.18.0-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.18.0.tar.gz (1.2 MB)
#   Downloading awscli-1.17.17-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.17.tar.gz (1.2 MB)
#   Downloading awscli-1.17.16-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.16.tar.gz (1.2 MB)
#   Downloading awscli-1.17.15-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.15.tar.gz (1.2 MB)
#   Downloading awscli-1.17.14-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.14.tar.gz (1.2 MB)
#   Downloading awscli-1.17.13-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.13.tar.gz (1.2 MB)
#   Downloading awscli-1.17.12-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.12.tar.gz (1.2 MB)
#   Downloading awscli-1.17.11-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.11.tar.gz (1.2 MB)
#   Downloading awscli-1.17.10-py2.py3-none-any.whl (2.9 MB)
#   Downloading awscli-1.17.10.tar.gz (1.2 MB)
#   Downloading awscli-1.17.9-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.9.tar.gz (1.1 MB)
#   Downloading awscli-1.17.8-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.8.tar.gz (1.1 MB)
#   Downloading awscli-1.17.7-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.7.tar.gz (1.1 MB)
#   Downloading awscli-1.17.6-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.6.tar.gz (1.1 MB)
#   Downloading awscli-1.17.5-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.5.tar.gz (1.1 MB)
#   Downloading awscli-1.17.4-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.4.tar.gz (1.1 MB)
#   Downloading awscli-1.17.3-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.3.tar.gz (1.1 MB)
#   Downloading awscli-1.17.2-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.2.tar.gz (1.1 MB)
#   Downloading awscli-1.17.1-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.1.tar.gz (1.1 MB)
#   Downloading awscli-1.17.0-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.17.0.tar.gz (1.1 MB)
#   Downloading awscli-1.16.314-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.16.314.tar.gz (1.1 MB)
#   Downloading awscli-1.16.313-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.16.313.tar.gz (1.1 MB)
#   Downloading awscli-1.16.312-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.16.312.tar.gz (1.1 MB)
#   Downloading awscli-1.16.311-py2.py3-none-any.whl (2.8 MB)
#   Downloading awscli-1.16.311.tar.gz (1.1 MB)
#   Downloading awscli-1.16.310-py2.py3-none-any.whl (2.7 MB)
#   Downloading awscli-1.16.310.tar.gz (1.1 MB)
#   Downloading awscli-1.16.309-py2.py3-none-any.whl (2.7 MB)
#   Downloading awscli-1.16.309.tar.gz (1.1 MB)
#   Downloading awscli-1.16.308-py2.py3-none-any.whl (2.7 MB)
#   Downloading awscli-1.16.308.tar.gz (1.1 MB)
#   Downloading awscli-1.16.307-py2.py3-none-any.whl (2.6 MB)
#   Downloading awscli-1.16.307.tar.gz (1.1 MB)
#   Downloading awscli-1.16.306-py2.py3-none-any.whl (2.6 MB)
#   Downloading awscli-1.16.306.tar.gz (1.1 MB)
#   Downloading awscli-1.16.305-py2.py3-none-any.whl (2.6 MB)
#   Downloading awscli-1.16.305.tar.gz (1.1 MB)
#   Downloading awscli-1.16.304-py2.py3-none-any.whl (2.6 MB)
#   Downloading awscli-1.16.304.tar.gz (1.1 MB)
#   Downloading awscli-1.16.303-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.303.tar.gz (1.0 MB)
#   Downloading awscli-1.16.302-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.302.tar.gz (1.0 MB)
#   Downloading awscli-1.16.301-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.301.tar.gz (1.0 MB)
#   Downloading awscli-1.16.300-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.300.tar.gz (1.0 MB)
#   Downloading awscli-1.16.299-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.299.tar.gz (1.0 MB)
#   Downloading awscli-1.16.298-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.298.tar.gz (1.0 MB)
#   Downloading awscli-1.16.297-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.297.tar.gz (1.0 MB)
#   Downloading awscli-1.16.296-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.296.tar.gz (1.0 MB)
#   Downloading awscli-1.16.295-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.295.tar.gz (1.0 MB)
#   Downloading awscli-1.16.294-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.294.tar.gz (1.0 MB)
#   Downloading awscli-1.16.293-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.293.tar.gz (1.0 MB)
#   Downloading awscli-1.16.292-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.292.tar.gz (1.0 MB)
#   Downloading awscli-1.16.291-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.291.tar.gz (1.0 MB)
#   Downloading awscli-1.16.290-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.290.tar.gz (1.0 MB)
#   Downloading awscli-1.16.289-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.289.tar.gz (1.0 MB)
#   Downloading awscli-1.16.288-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.288.tar.gz (1.0 MB)
#   Downloading awscli-1.16.287-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.287.tar.gz (1.0 MB)
#   Downloading awscli-1.16.286-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.286.tar.gz (1.0 MB)
#   Downloading awscli-1.16.285-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.285.tar.gz (1.0 MB)
#   Downloading awscli-1.16.284-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.284.tar.gz (1.0 MB)
#   Downloading awscli-1.16.283-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.283.tar.gz (1.0 MB)
#   Downloading awscli-1.16.282-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.282.tar.gz (1.0 MB)
#   Downloading awscli-1.16.281-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.281.tar.gz (1.0 MB)
#   Downloading awscli-1.16.280-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.280.tar.gz (1.0 MB)
#   Downloading awscli-1.16.279-py2.py3-none-any.whl (2.5 MB)
#   Downloading awscli-1.16.279.tar.gz (1.0 MB)
#   Downloading awscli-1.16.278-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.278.tar.gz (989 kB)
#   Downloading awscli-1.16.277-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.277.tar.gz (990 kB)
#   Downloading awscli-1.16.276-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.276.tar.gz (989 kB)
#   Downloading awscli-1.16.275-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.275.tar.gz (989 kB)
#   Downloading awscli-1.16.274-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.274.tar.gz (990 kB)
#   Downloading awscli-1.16.273-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.273.tar.gz (989 kB)
#   Downloading awscli-1.16.272-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.272.tar.gz (989 kB)
#   Downloading awscli-1.16.271-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.271.tar.gz (989 kB)
#   Downloading awscli-1.16.270-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.270.tar.gz (989 kB)
#   Downloading awscli-1.16.269-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.269.tar.gz (989 kB)
#   Downloading awscli-1.16.268-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.268.tar.gz (989 kB)
#   Downloading awscli-1.16.267-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.267.tar.gz (989 kB)
#   Downloading awscli-1.16.266-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.266.tar.gz (986 kB)
#   Downloading awscli-1.16.265-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.265.tar.gz (986 kB)
#   Downloading awscli-1.16.264-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.264.tar.gz (987 kB)
#   Downloading awscli-1.16.263-py2.py3-none-any.whl (2.4 MB)
#   Downloading awscli-1.16.263.tar.gz (986 kB)
#   Downloading awscli-1.16.262-py2.py3-none-any.whl (2.3 MB)
#   Downloading awscli-1.16.262.tar.gz (984 kB)
#   Downloading awscli-1.16.261-py2.py3-none-any.whl (2.3 MB)
#   Downloading awscli-1.16.261.tar.gz (984 kB)
#   Downloading awscli-1.16.260-py2.py3-none-any.whl (2.3 MB)
#   Downloading awscli-1.16.260.tar.gz (976 kB)
#   Downloading awscli-1.16.259-py2.py3-none-any.whl (2.3 MB)
#   Downloading awscli-1.16.259.tar.gz (966 kB)
#   Downloading awscli-1.16.258-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.258.tar.gz (950 kB)
#   Downloading awscli-1.16.257-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.257.tar.gz (950 kB)
#   Downloading awscli-1.16.256-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.256.tar.gz (950 kB)
#   Downloading awscli-1.16.255-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.255.tar.gz (950 kB)
#   Downloading awscli-1.16.254-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.254.tar.gz (936 kB)
#   Downloading awscli-1.16.253-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.253.tar.gz (936 kB)
#   Downloading awscli-1.16.252-py2.py3-none-any.whl (2.2 MB)
#   Downloading awscli-1.16.252.tar.gz (931 kB)
#   Downloading awscli-1.16.251-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.251.tar.gz (911 kB)
#   Downloading awscli-1.16.250-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.250.tar.gz (911 kB)
#   Downloading awscli-1.16.249-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.249.tar.gz (911 kB)
#   Downloading awscli-1.16.248-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.248.tar.gz (911 kB)
#   Downloading awscli-1.16.247-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.247.tar.gz (911 kB)
#   Downloading awscli-1.16.246-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.246.tar.gz (887 kB)
#   Downloading awscli-1.16.245-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.245.tar.gz (887 kB)
#   Downloading awscli-1.16.244-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.244.tar.gz (887 kB)
#   Downloading awscli-1.16.243-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.243.tar.gz (887 kB)
#   Downloading awscli-1.16.242-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.242.tar.gz (887 kB)
#   Downloading awscli-1.16.241-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.241.tar.gz (883 kB)
#   Downloading awscli-1.16.240-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.240.tar.gz (880 kB)
#   Downloading awscli-1.16.239-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.239.tar.gz (880 kB)
#   Downloading awscli-1.16.238-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.238.tar.gz (880 kB)
#   Downloading awscli-1.16.237-py2.py3-none-any.whl (2.1 MB)
#   Downloading awscli-1.16.237.tar.gz (880 kB)
#   Downloading awscli-1.16.236-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.236.tar.gz (874 kB)
#   Downloading awscli-1.16.235-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.235.tar.gz (874 kB)
#   Downloading awscli-1.16.234-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.234.tar.gz (874 kB)
#   Downloading awscli-1.16.233-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.233.tar.gz (874 kB)
#   Downloading awscli-1.16.232-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.232.tar.gz (874 kB)
#   Downloading awscli-1.16.231-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.231.tar.gz (872 kB)
#   Downloading awscli-1.16.230-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.230.tar.gz (857 kB)
#   Downloading awscli-1.16.229-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.229.tar.gz (857 kB)
#   Downloading awscli-1.16.228-py2.py3-none-any.whl (2.0 MB)
#   Downloading awscli-1.16.228.tar.gz (857 kB)
#   Downloading awscli-1.16.227-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.227.tar.gz (844 kB)
#   Downloading awscli-1.16.226-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.226.tar.gz (843 kB)
#   Downloading awscli-1.16.225-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.225.tar.gz (843 kB)
#   Downloading awscli-1.16.224-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.224.tar.gz (844 kB)
#   Downloading awscli-1.16.223-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.223.tar.gz (843 kB)
#   Downloading awscli-1.16.222-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.222.tar.gz (844 kB)
#   Downloading awscli-1.16.221-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.221.tar.gz (843 kB)
#   Downloading awscli-1.16.220-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.220.tar.gz (840 kB)
#   Downloading awscli-1.16.219-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.219.tar.gz (840 kB)
#   Downloading awscli-1.16.218-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.218.tar.gz (831 kB)
#   Downloading awscli-1.16.217-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.217.tar.gz (831 kB)
#   Downloading awscli-1.16.216-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.216.tar.gz (831 kB)
#   Downloading awscli-1.16.215-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.215.tar.gz (820 kB)
#   Downloading awscli-1.16.214-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.214.tar.gz (818 kB)
#   Downloading awscli-1.16.213-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.213.tar.gz (817 kB)
#   Downloading awscli-1.16.212-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.212.tar.gz (815 kB)
#   Downloading awscli-1.16.211-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.211.tar.gz (815 kB)
#   Downloading awscli-1.16.210-py2.py3-none-any.whl (1.9 MB)
#   Downloading awscli-1.16.210.tar.gz (815 kB)
#   Downloading awscli-1.16.209-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.209.tar.gz (803 kB)
#   Downloading awscli-1.16.208-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.208.tar.gz (803 kB)
#   Downloading awscli-1.16.207-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.207.tar.gz (803 kB)
#   Downloading awscli-1.16.206-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.206.tar.gz (787 kB)
#   Downloading awscli-1.16.205-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.205.tar.gz (787 kB)
#   Downloading awscli-1.16.204-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.204.tar.gz (787 kB)
#   Downloading awscli-1.16.203-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.203.tar.gz (787 kB)
#   Downloading awscli-1.16.202-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.202.tar.gz (787 kB)
#   Downloading awscli-1.16.201-py2.py3-none-any.whl (1.8 MB)
#   Downloading awscli-1.16.201.tar.gz (787 kB)
#   Downloading awscli-1.16.200-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.200.tar.gz (773 kB)
#   Downloading awscli-1.16.199-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.199.tar.gz (771 kB)
#   Downloading awscli-1.16.198-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.198.tar.gz (768 kB)
#   Downloading awscli-1.16.197-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.197.tar.gz (761 kB)
#   Downloading awscli-1.16.196-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.196.tar.gz (761 kB)
#   Downloading awscli-1.16.195-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.195.tar.gz (761 kB)
#   Downloading awscli-1.16.194-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.194.tar.gz (761 kB)
#   Downloading awscli-1.16.193-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.193.tar.gz (757 kB)
#   Downloading awscli-1.16.192-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.192.tar.gz (756 kB)
#   Downloading awscli-1.16.191-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.191.tar.gz (756 kB)
#   Downloading awscli-1.16.190-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.190.tar.gz (757 kB)
#   Downloading awscli-1.16.189-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.189.tar.gz (757 kB)
#   Downloading awscli-1.16.188-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.188.tar.gz (756 kB)
#   Downloading awscli-1.16.187-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.187.tar.gz (756 kB)
#   Downloading awscli-1.16.186-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.186.tar.gz (756 kB)
#   Downloading awscli-1.16.185-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.185.tar.gz (756 kB)
#   Downloading awscli-1.16.184-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.184.tar.gz (756 kB)
#   Downloading awscli-1.16.183-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.183.tar.gz (752 kB)
#   Downloading awscli-1.16.182-py2.py3-none-any.whl (1.7 MB)
#   Downloading awscli-1.16.182.tar.gz (752 kB)
#   Downloading awscli-1.16.181-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.181.tar.gz (739 kB)
#   Downloading awscli-1.16.180-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.180.tar.gz (739 kB)
#   Downloading awscli-1.16.179-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.179.tar.gz (739 kB)
#   Downloading awscli-1.16.178-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.178.tar.gz (739 kB)
#   Downloading awscli-1.16.177-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.177.tar.gz (739 kB)
#   Downloading awscli-1.16.176-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.176.tar.gz (739 kB)
#   Downloading awscli-1.16.175-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.175.tar.gz (739 kB)
#   Downloading awscli-1.16.174-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.174.tar.gz (737 kB)
#   Downloading awscli-1.16.173-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.173.tar.gz (736 kB)
#   Downloading awscli-1.16.172-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.172.tar.gz (736 kB)
#   Downloading awscli-1.16.171-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.171.tar.gz (733 kB)
#   Downloading awscli-1.16.170-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.170.tar.gz (726 kB)
#   Downloading awscli-1.16.169-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.169.tar.gz (724 kB)
#   Downloading awscli-1.16.168-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.168.tar.gz (724 kB)
#   Downloading awscli-1.16.167-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.167.tar.gz (724 kB)
#   Downloading awscli-1.16.166-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.166.tar.gz (721 kB)
#   Downloading awscli-1.16.165-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.165.tar.gz (721 kB)
#   Downloading awscli-1.16.164-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.164.tar.gz (721 kB)
#   Downloading awscli-1.16.163-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.163.tar.gz (721 kB)
#   Downloading awscli-1.16.162-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.162.tar.gz (721 kB)
#   Downloading awscli-1.16.161-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.161.tar.gz (721 kB)
#   Downloading awscli-1.16.160-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.160.tar.gz (715 kB)
#   Downloading awscli-1.16.159-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.159.tar.gz (715 kB)
#   Downloading awscli-1.16.158-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.158.tar.gz (715 kB)
#   Downloading awscli-1.16.157-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.157.tar.gz (715 kB)
#   Downloading awscli-1.16.156-py2.py3-none-any.whl (1.6 MB)
#   Downloading awscli-1.16.156.tar.gz (715 kB)
#   Downloading awscli-1.16.155-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.155.tar.gz (703 kB)
#   Downloading awscli-1.16.154-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.154.tar.gz (703 kB)
#   Downloading awscli-1.16.153-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.153.tar.gz (703 kB)
#   Downloading awscli-1.16.152-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.152.tar.gz (703 kB)
#   Downloading awscli-1.16.151-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.151.tar.gz (703 kB)
#   Downloading awscli-1.16.150-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.150.tar.gz (703 kB)
#   Downloading awscli-1.16.149-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.149.tar.gz (703 kB)
#   Downloading awscli-1.16.148-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.148.tar.gz (703 kB)
#   Downloading awscli-1.16.147-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.147.tar.gz (703 kB)
#   Downloading awscli-1.16.146-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.146.tar.gz (700 kB)
#   Downloading awscli-1.16.145-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.145.tar.gz (698 kB)
#   Downloading awscli-1.16.144-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.144.tar.gz (690 kB)
#   Downloading awscli-1.16.143-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.143.tar.gz (690 kB)
#   Downloading awscli-1.16.142-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.142.tar.gz (688 kB)
#   Downloading awscli-1.16.141-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.141.tar.gz (688 kB)
#   Downloading awscli-1.16.140-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.140.tar.gz (685 kB)
#   Downloading awscli-1.16.139-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.139.tar.gz (684 kB)
#   Downloading awscli-1.16.138-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.138.tar.gz (684 kB)
#   Downloading awscli-1.16.137-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.137.tar.gz (680 kB)
#   Downloading awscli-1.16.136-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.136.tar.gz (680 kB)
#   Downloading awscli-1.16.135-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.135.tar.gz (680 kB)
#   Downloading awscli-1.16.134-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.134.tar.gz (679 kB)
#   Downloading awscli-1.16.133-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.133.tar.gz (680 kB)
#   Downloading awscli-1.16.132-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.132.tar.gz (680 kB)
#   Downloading awscli-1.16.131-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.131.tar.gz (679 kB)
#   Downloading awscli-1.16.130-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.130.tar.gz (680 kB)
#   Downloading awscli-1.16.129-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.129.tar.gz (679 kB)
#   Downloading awscli-1.16.128-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.128.tar.gz (679 kB)
#   Downloading awscli-1.16.127-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.127.tar.gz (679 kB)
#   Downloading awscli-1.16.126-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.126.tar.gz (679 kB)
#   Downloading awscli-1.16.125-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.125.tar.gz (679 kB)
#   Downloading awscli-1.16.124-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.124.tar.gz (680 kB)
#   Downloading awscli-1.16.123-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.123.tar.gz (679 kB)
#   Downloading awscli-1.16.122-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.122.tar.gz (679 kB)
#   Downloading awscli-1.16.121-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.121.tar.gz (679 kB)
#   Downloading awscli-1.16.120-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.120.tar.gz (679 kB)
#   Downloading awscli-1.16.119-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.119.tar.gz (679 kB)
#   Downloading awscli-1.16.118-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.118.tar.gz (679 kB)
#   Downloading awscli-1.16.117-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.117.tar.gz (679 kB)
#   Downloading awscli-1.16.116-py2.py3-none-any.whl (1.5 MB)
#   Downloading awscli-1.16.116.tar.gz (669 kB)
#   Downloading awscli-1.16.115-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.115.tar.gz (668 kB)
#   Downloading awscli-1.16.114-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.114.tar.gz (668 kB)
#   Downloading awscli-1.16.113-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.113.tar.gz (668 kB)
#   Downloading awscli-1.16.112-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.112.tar.gz (668 kB)
#   Downloading awscli-1.16.111-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.111.tar.gz (668 kB)
#   Downloading awscli-1.16.110-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.110.tar.gz (668 kB)
#   Downloading awscli-1.16.109-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.109.tar.gz (667 kB)
#   Downloading awscli-1.16.108-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.108.tar.gz (667 kB)
#   Downloading awscli-1.16.107-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.107.tar.gz (667 kB)
#   Downloading awscli-1.16.106-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.106.tar.gz (667 kB)
#   Downloading awscli-1.16.105-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.105.tar.gz (667 kB)
#   Downloading awscli-1.16.104-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.104.tar.gz (667 kB)
#   Downloading awscli-1.16.103-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.103.tar.gz (667 kB)
#   Downloading awscli-1.16.102-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.102.tar.gz (667 kB)
#   Downloading awscli-1.16.101-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.101.tar.gz (667 kB)
#   Downloading awscli-1.16.100-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.100.tar.gz (668 kB)
#   Downloading awscli-1.16.99-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.99.tar.gz (656 kB)
#   Downloading awscli-1.16.98-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.98.tar.gz (656 kB)
#   Downloading awscli-1.16.97-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.97.tar.gz (656 kB)
#   Downloading awscli-1.16.96-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.96.tar.gz (655 kB)
#   Downloading awscli-1.16.95-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.95.tar.gz (655 kB)
#   Downloading awscli-1.16.94-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.94.tar.gz (655 kB)
#   Downloading awscli-1.16.93-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.93.tar.gz (655 kB)
#   Downloading awscli-1.16.92-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.92.tar.gz (655 kB)
#   Downloading awscli-1.16.91-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.91.tar.gz (655 kB)
#   Downloading awscli-1.16.90-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.90.tar.gz (655 kB)
#   Downloading awscli-1.16.89-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.89.tar.gz (655 kB)
#   Downloading awscli-1.16.88-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.88.tar.gz (655 kB)
#   Downloading awscli-1.16.87-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.87.tar.gz (655 kB)
#   Downloading awscli-1.16.86-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.86.tar.gz (655 kB)
#   Downloading awscli-1.16.85-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.85.tar.gz (655 kB)
#   Downloading awscli-1.16.84-py2.py3-none-any.whl (1.4 MB)
#   Downloading awscli-1.16.84.tar.gz (655 kB)
# ...
#   Downloading python_dotenv-0.13.0-py2.py3-none-any.whl (17 kB)
#   Downloading python-dotenv-0.13.0.tar.gz (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Downloading python_dotenv-0.12.0-py2.py3-none-any.whl (17 kB)
#   Downloading python-dotenv-0.12.0.tar.gz (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Downloading python_dotenv-0.11.0-py2.py3-none-any.whl (17 kB)
#   Downloading python-dotenv-0.11.0.tar.gz (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Downloading python_dotenv-0.10.5-py2.py3-none-any.whl (17 kB)
#   Downloading python-dotenv-0.10.5.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Downloading python_dotenv-0.10.4-py2.py3-none-any.whl (16 kB)
#   Downloading python-dotenv-0.10.4.tar.gz (28 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
#   Downloading python_dotenv-0.10.3-py2.py3-none-any.whl (16 kB)
#   Downloading python-dotenv-0.10.3.tar.gz (26 kB)
#   Downloading python_dotenv-0.10.2-py2.py3-none-any.whl (15 kB)
#   Downloading python-dotenv-0.10.2.tar.gz (30 kB)
#   Downloading python_dotenv-0.10.1-py2.py3-none-any.whl (19 kB)
#   Downloading python-dotenv-0.10.1.tar.gz (20 kB)
#   Downloading python_dotenv-0.10.0-py2.py3-none-any.whl (18 kB)
#   Downloading python-dotenv-0.10.0.tar.gz (19 kB)
#   Downloading python_dotenv-0.9.1-py2.py3-none-any.whl (17 kB)
#   Downloading python-dotenv-0.9.1.tar.gz (17 kB)
#   Downloading python_dotenv-0.9.0-py2.py3-none-any.whl (17 kB)
#   Downloading python-dotenv-0.9.0.tar.gz (17 kB)
#   Downloading python_dotenv-0.8.2-py2.py3-none-any.whl (16 kB)
#   Downloading python-dotenv-0.8.2.tar.gz (16 kB)
#   Downloading python_dotenv-0.8.1-py2.py3-none-any.whl (16 kB)
#   Downloading python-dotenv-0.8.1.tar.gz (16 kB)
#   Downloading python_dotenv-0.8.0-py2.py3-none-any.whl (15 kB)
#   Downloading python-dotenv-0.8.0.tar.gz (15 kB)
#   Downloading python_dotenv-0.7.1-py2.py3-none-any.whl (14 kB)
#   Downloading python-dotenv-0.7.1.tar.gz (10 kB)
#   Downloading python_dotenv-0.7.0-py2.py3-none-any.whl (13 kB)
#   Downloading python-dotenv-0.7.0.tar.gz (10 kB)
#   Downloading python_dotenv-0.6.5-py2.py3-none-any.whl (13 kB)
#   Downloading python-dotenv-0.6.5.tar.gz (9.9 kB)
#   Downloading python_dotenv-0.6.4-py2.py3-none-any.whl (13 kB)
#   Downloading python-dotenv-0.6.4.tar.gz (9.8 kB)
#   Downloading python_dotenv-0.6.3-py2.py3-none-any.whl (12 kB)
#   Downloading python-dotenv-0.6.3.tar.gz (9.8 kB)
#   Downloading python-dotenv-0.6.2.tar.gz (9.7 kB)
#   Downloading python_dotenv-0.6.1-py2.py3-none-any.whl (12 kB)
#   Downloading python-dotenv-0.6.1.tar.gz (9.6 kB)
#   Downloading python_dotenv-0.6.0-py2.py3-none-any.whl (12 kB)
#   Downloading python-dotenv-0.6.0.tar.gz (8.1 kB)
#   Downloading python_dotenv-0.5.1-py2.py3-none-any.whl (11 kB)
#   Downloading python-dotenv-0.5.1.tar.gz (7.4 kB)
#   Downloading python_dotenv-0.5.0-py2.py3-none-any.whl (11 kB)
#   Downloading python-dotenv-0.5.0.tar.gz (7.4 kB)
#   Downloading python_dotenv-0.4.0-py2.py3-none-any.whl (10 kB)
#   Downloading python-dotenv-0.4.0.tar.gz (6.6 kB)
#   Downloading python_dotenv-0.3.0-py2.py3-none-any.whl (8.9 kB)
#   Downloading python-dotenv-0.3.0.tar.gz (6.1 kB)
#   Downloading python_dotenv-0.2.0-py2.py3-none-any.whl (8.9 kB)
#   Downloading python-dotenv-0.2.0.tar.gz (6.1 kB)
#   Downloading python_dotenv-0.1.5-py2.py3-none-any.whl (9.2 kB)
#   Downloading python-dotenv-0.1.5.tar.gz (6.2 kB)
#   Downloading python_dotenv-0.1.3-py2.py3-none-any.whl (4.2 kB)
#   Downloading python-dotenv-0.1.3.tar.gz (3.1 kB)
#   Downloading python_dotenv-0.1.2-py2.py3-none-any.whl (4.3 kB)
#   Downloading python-dotenv-0.1.2.tar.gz (2.9 kB)
#   Downloading python-dotenv-0.1.0.tar.gz (2.4 kB)
# Requirement already satisfied: pytest-sugar in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from -r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 3)) (0.9.4)
# Collecting pytest-sugar
#   Using cached pytest_sugar-0.9.4-py2.py3-none-any.whl
#   Downloading pytest-sugar-0.9.3.tar.gz (12 kB)
#   Downloading pytest_sugar-0.9.2-py2.py3-none-any.whl (8.8 kB)
#   Downloading pytest-sugar-0.9.2.tar.gz (12 kB)
#   Downloading pytest-sugar-0.9.1.tar.gz (11 kB)
#   Downloading pytest-sugar-0.9.0.tar.gz (11 kB)
#   Downloading pytest_sugar-0.8.0-py2.py3-none-any.whl (8.8 kB)
#   Downloading pytest-sugar-0.8.0.tar.gz (11 kB)
#   Downloading pytest-sugar-0.7.1.tar.gz (10 kB)
#   Downloading pytest-sugar-0.7.0.tar.gz (10 kB)
#   Downloading pytest-sugar-0.6.0.tar.gz (9.7 kB)
#   Downloading pytest-sugar-0.5.1.tar.gz (9.2 kB)
#   Downloading pytest-sugar-0.5.0.tar.gz (9.2 kB)
#   Downloading pytest-sugar-0.4.0.tar.gz (9.0 kB)
#   Downloading pytest-sugar-0.3.6.tar.gz (8.4 kB)
#   Downloading pytest-sugar-0.3.5.tar.gz (7.9 kB)
#   Downloading pytest-sugar-0.3.4.tar.gz (8.0 kB)
#   Downloading pytest-sugar-0.3.3.tar.gz (7.9 kB)
#   Downloading pytest-sugar-0.3.2.tar.gz (7.4 kB)
#   Downloading pytest-sugar-0.3.1.tar.gz (4.7 kB)
#   Downloading pytest-sugar-0.3.0.tar.gz (4.7 kB)
#   Downloading pytest-sugar-0.2.4.tar.gz (5.0 kB)
#   Downloading pytest-sugar-0.2.3.tar.gz (5.0 kB)
#   Downloading pytest-sugar-0.2.2.tar.gz (5.0 kB)
#   Downloading pytest-sugar-0.2.1.tar.gz (5.0 kB)
#   Downloading pytest-sugar-0.2.0.tar.gz (4.9 kB)
# Requirement already satisfied: pytest-cov in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from -r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (2.10.1)
# Collecting pytest-cov
#   Using cached pytest_cov-2.10.1-py2.py3-none-any.whl (19 kB)
#   Downloading pytest-cov-2.10.1.tar.gz (56 kB)
#   Downloading pytest_cov-2.10.0-py2.py3-none-any.whl (19 kB)
#   Downloading pytest-cov-2.10.0.tar.gz (54 kB)
#   Downloading pytest_cov-2.9.0-py2.py3-none-any.whl (19 kB)
#   Downloading pytest-cov-2.9.0.tar.gz (54 kB)
#   Using cached pytest_cov-2.8.1-py2.py3-none-any.whl (18 kB)
#   Downloading pytest-cov-2.8.1.tar.gz (47 kB)
#   Downloading pytest_cov-2.8.0-py2.py3-none-any.whl (18 kB)
#   Downloading pytest-cov-2.8.0.tar.gz (47 kB)
#   Downloading pytest_cov-2.7.1-py2.py3-none-any.whl (17 kB)
#   Downloading pytest-cov-2.7.1.tar.gz (42 kB)
#   Downloading pytest_cov-2.7.0-py2.py3-none-any.whl (17 kB)
#   Downloading pytest-cov-2.7.0.tar.gz (1.8 MB)
#   Downloading pytest_cov-2.6.1-py2.py3-none-any.whl (16 kB)
#   Downloading pytest-cov-2.6.1.tar.gz (35 kB)
#   Downloading pytest_cov-2.6.0-py2.py3-none-any.whl (14 kB)
#   Downloading pytest-cov-2.6.0.tar.gz (33 kB)
#   Downloading pytest_cov-2.5.1-py2.py3-none-any.whl (21 kB)
#   Downloading pytest-cov-2.5.1.tar.gz (36 kB)
#   Downloading pytest_cov-2.5.0-py2.py3-none-any.whl (21 kB)
#   Downloading pytest-cov-2.5.0.tar.gz (35 kB)
#   Downloading pytest_cov-2.4.0-py2.py3-none-any.whl (20 kB)
#   Downloading pytest-cov-2.4.0.tar.gz (37 kB)
#   Downloading pytest_cov-2.3.1-py2.py3-none-any.whl (19 kB)
#   Downloading pytest-cov-2.3.1.tar.gz (35 kB)
#   Downloading pytest_cov-2.3.0-py2.py3-none-any.whl (18 kB)
#   Downloading pytest-cov-2.3.0.tar.gz (36 kB)
#   Downloading pytest_cov-2.2.1-py2.py3-none-any.whl (16 kB)
#   Downloading pytest-cov-2.2.1.tar.gz (33 kB)
#   Downloading pytest_cov-2.2.0-py2.py3-none-any.whl (16 kB)
#   Downloading pytest-cov-2.2.0.tar.gz (29 kB)
#   Downloading pytest_cov-2.1.0-py2.py3-none-any.whl (16 kB)
#   Downloading pytest-cov-2.1.0.tar.gz (25 kB)
#   Downloading pytest_cov-2.0.0-py2.py3-none-any.whl (15 kB)
#   Downloading pytest-cov-2.0.0.tar.gz (26 kB)
#   Downloading pytest-cov-1.8.1.tar.gz (8.6 kB)
#   Downloading pytest-cov-1.8.0.tar.gz (8.6 kB)
#   Downloading pytest-cov-1.7.0.tar.gz (8.6 kB)
#   Downloading pytest-cov-1.6.tar.gz (8.3 kB)
#   Downloading pytest-cov-1.5.tar.gz (7.5 kB)
#   Downloading pytest-cov-1.4.tar.gz (7.4 kB)
#   Downloading pytest-cov-1.3.tar.gz (7.1 kB)
#   Downloading pytest-cov-1.2.tar.gz (7.1 kB)
#   Downloading pytest-cov-1.1.tar.gz (7.0 kB)
#   Downloading pytest-cov-1.0.tar.gz (6.9 kB)
#   Downloading pytest-cov-0.15.tar.gz (12 kB)
#   Downloading pytest-cov-0.14.tar.gz (12 kB)
#   Downloading pytest-cov-0.13.tar.gz (12 kB)
#   Downloading pytest-cov-0.12.tar.gz (12 kB)
#   Downloading pytest-cov-0.11.tar.gz (9.5 kB)
#   Downloading pytest-cov-0.10.tar.gz (9.5 kB)
#   Downloading pytest-cov-0.9.tar.gz (9.3 kB)
#   Downloading pytest-cov-0.8.tar.gz (9.4 kB)
#   Downloading pytest-cov-0.7.tar.gz (9.4 kB)
#   Downloading pytest-cov-0.6.tar.gz (6.8 kB)
# Requirement already satisfied: colorama<0.4.4,>=0.2.5 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (0.15.2)
# Collecting botocore==1.19.36
#   Downloading botocore-1.19.36-py2.py3-none-any.whl (7.1 MB)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (0.3.3)
# Requirement already satisfied: PyYAML<5.4,>=3.10 in /Users/val/.local/lib/python3.8/site-packages (from awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (5.3)
# Requirement already satisfied: rsa<=4.5.0,>=3.1.2 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (4.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from botocore==1.19.36->awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from botocore==1.19.36->awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (1.25.11)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from botocore==1.19.36->awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: six>=1.5 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.19.36->awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from rsa<=4.5.0,>=3.1.2->awscli->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: coverage>=4.4 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (5.3)
# Requirement already satisfied: pytest>=4.6 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (6.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (20.3.0)
# Requirement already satisfied: iniconfig in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: packaging in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (20.4)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: toml in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from pytest-sugar->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/val/opt/anaconda3/envs/microscopeProject/lib/python3.8/site-packages (from packaging->pytest>=4.6->pytest-cov->-r /Users/val/Google Drive/projects/microscopeProject/microscope/condaenv.ercvk7sy.requirements.txt (line 4)) (2.4.7)
# Installing collected packages: botocore, microscope, awscli
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.19.35
#     Uninstalling botocore-1.19.35:
#       Successfully uninstalled botocore-1.19.35
#   Attempting uninstall: microscope
#     Found existing installation: microscope 0.1.0
#     Uninstalling microscope-0.1.0:
#       Successfully uninstalled microscope-0.1.0
#   Running setup.py develop for microscope
#   Attempting uninstall: awscli
#     Found existing installation: awscli 1.18.195
#     Uninstalling awscli-1.18.195:
#       Successfully uninstalled awscli-1.18.195
# Successfully installed awscli-1.18.196 botocore-1.19.36 microscope
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate microscopeProject
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # At the beginning of your notebook

# %%
# make sure you have two magic functions imported at the beginning of your notebook
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import custom functions

# %%
from microscope import Foo
# Out:
#   File "<ipython-input-10-65761f8deec2>", line 1
#     from "../microscope" import Foo
#          ^
# SyntaxError: invalid syntax

# %%
Foo.print_hi("ame")
# Out:
# Hi, ame

# %%
# while in test_env, export the packages used to an environment file
conda env export > environment.yaml

# %%
# Now we are no longer in test_env, we can delete it
conda env remove --name test_env

# %%
#Making the environment again from the yaml file
conda env create --file environment.yaml
